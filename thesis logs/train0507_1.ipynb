# %%
import cv2
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization, GaussianNoise, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
size = 512
channels =  1  #input image format
input_img = Input(shape=(size, size, channels))
#print(input_img)

# %%
# Encoder
x = GaussianNoise(0.1)(input_img)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.2)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.2)(x)

# Decoder
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Dropout(0.2)(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Dropout(0.2)(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.0001), loss='mse')

# %%
def preprocess_image(image):
    # Resize the image to ensure consistent input size
    image = cv2.resize(image, (size, size))

    # Apply Gaussian Blurring to smooth the image and reduce noise
    image = cv2.GaussianBlur(image, (5, 5), 0)

    if len(image.shape) == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Convert the image to 8-bit if it's not already
    if image.dtype != np.uint8:
        image = np.uint8(image)
    
    # Apply adaptive thresholding to create a binary image
    # This will help in highlighting significant features
    image = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                  cv2.THRESH_BINARY, 11, 2)
    
    # Use morphological closing to close small holes in the foreground
    kernel = np.ones((5, 5), np.uint8)
    image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

    # Dilate the result to make the objects more apparent
    image = cv2.dilate(image, kernel, iterations=1)

    # Edge detection to highlight boundaries
    image = cv2.Canny(image, 100, 200)

    # Normalize the image to have values between 0 and 1
    image = np.expand_dims(image, axis=-1) / 255.0
    
    return image

def custom_preprocessor(img):
    # Assuming 'img' is a NumPy array of image data
    return preprocess_image(img)

# Setup the data generator
datagen = ImageDataGenerator(
    preprocessing_function=custom_preprocessor,
    validation_split=0.15  # if you have validation data
)

# %%
train_generator = datagen.flow_from_directory(
    'dataset',  #path to dataset
    target_size=(size, size),
    color_mode='grayscale',
    batch_size=16,
    class_mode='input',
    subset='training'
)
validation_generator = datagen.flow_from_directory(
    'dataset',  #path to dataset
    target_size=(size, size),
    color_mode='grayscale',
    batch_size=16,
    class_mode='input',
    subset='validation'
)
# Out:
# Found 152 images belonging to 6 classes.
# Found 25 images belonging to 6 classes.

# %%
# Define early stopping callback
early_stopper = EarlyStopping(monitor='val_loss', patience=30, verbose=1, restore_best_weights=True)

# Now include the callback in the fit method
autoencoder.fit(
    train_generator,
    epochs=200,
    validation_data=validation_generator,
    callbacks=[early_stopper]
)
# Out:
# Epoch 1/200
# /Users/yong/anaconda3/envs/plard/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - loss: 0.1798 - val_loss: 0.2402
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - loss: 0.1164 - val_loss: 0.2284
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - loss: 0.0718 - val_loss: 0.2166
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - loss: 0.0421 - val_loss: 0.2058
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - loss: 0.0266 - val_loss: 0.1965
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 58s 6s/step - loss: 0.0177 - val_loss: 0.1894
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - loss: 0.0131 - val_loss: 0.1837
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0106 - val_loss: 0.1788
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - loss: 0.0091 - val_loss: 0.1745
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0082 - val_loss: 0.1708
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0076 - val_loss: 0.1675
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0071 - val_loss: 0.1646
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0067 - val_loss: 0.1620
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0065 - val_loss: 0.1595
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0063 - val_loss: 0.1570
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0062 - val_loss: 0.1546
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0060 - val_loss: 0.1525
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0058 - val_loss: 0.1505
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0058 - val_loss: 0.1485
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0058 - val_loss: 0.1467
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - loss: 0.0056 - val_loss: 0.1450
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - loss: 0.0056 - val_loss: 0.1433
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - loss: 0.0056 - val_loss: 0.1416
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0056 - val_loss: 0.1399
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - loss: 0.0056 - val_loss: 0.1381
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0055 - val_loss: 0.1363
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0055 - val_loss: 0.1344
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - loss: 0.0054 - val_loss: 0.1324
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - loss: 0.0054 - val_loss: 0.1303
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - loss: 0.0053 - val_loss: 0.1280
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - loss: 0.0053 - val_loss: 0.1255
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - loss: 0.0053 - val_loss: 0.1230
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0053 - val_loss: 0.1205
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - loss: 0.0053 - val_loss: 0.1177
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0053 - val_loss: 0.1147
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - loss: 0.0053 - val_loss: 0.1114
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0053 - val_loss: 0.1078
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0053 - val_loss: 0.1040
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0053 - val_loss: 0.0999
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0052 - val_loss: 0.0956
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0052 - val_loss: 0.0909
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0052 - val_loss: 0.0860
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0052 - val_loss: 0.0810
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0053 - val_loss: 0.0752
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - loss: 0.0052 - val_loss: 0.0693
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0051 - val_loss: 0.0629
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - loss: 0.0052 - val_loss: 0.0571
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0052 - val_loss: 0.0514
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0052 - val_loss: 0.0460
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0052 - val_loss: 0.0408
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - loss: 0.0051 - val_loss: 0.0360
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - loss: 0.0052 - val_loss: 0.0315
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0052 - val_loss: 0.0275
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - loss: 0.0052 - val_loss: 0.0240
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - loss: 0.0052 - val_loss: 0.0210
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0052 - val_loss: 0.0185
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - loss: 0.0052 - val_loss: 0.0164
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 36s 4s/step - loss: 0.0051 - val_loss: 0.0145
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0128
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0114
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0103
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 36s 4s/step - loss: 0.0050 - val_loss: 0.0093
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 36s 4s/step - loss: 0.0052 - val_loss: 0.0085
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0079
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0073
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0069
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0051 - val_loss: 0.0063
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0058
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0052
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 early_stopper = EarlyStopping(monitor='val_loss', patience=30, verbose=1, restore_best_weights=True)
#       4 # Now include the callback in the fit method
# ----> 5 autoencoder.fit(
#       6     train_generator,
#       7     epochs=200,
#       8     validation_data=validation_generator,
#       9     callbacks=[early_stopper]
#      10 )
#
# File ~/anaconda3/envs/plard/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/plard/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:330, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     328 callbacks.on_train_batch_begin(step)
#     329 logs = self.train_function(iterator)
# --> 330 callbacks.on_train_batch_end(
#     331     step, self._pythonify_logs(logs)
#     332 )
#     333 if self.stop_training:
#     334     break
#
# File ~/anaconda3/envs/plard/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:106, in CallbackList.on_train_batch_end(self, batch, logs)
#     104 logs = logs or {}
#     105 for callback in self.callbacks:
# --> 106     callback.on_train_batch_end(batch, logs=logs)
#
# File ~/anaconda3/envs/plard/lib/python3.10/site-packages/keras/src/callbacks/progbar_logger.py:58, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#      57 def on_train_batch_end(self, batch, logs=None):
# ---> 58     self._update_progbar(batch, logs)
#
# File ~/anaconda3/envs/plard/lib/python3.10/site-packages/keras/src/callbacks/progbar_logger.py:95, in ProgbarLogger._update_progbar(self, batch, logs)
#      92 self.seen = batch + 1  # One-indexed.
#      94 if self.verbose == 1:
# ---> 95     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~/anaconda3/envs/plard/lib/python3.10/site-packages/keras/src/utils/progbar.py:182, in Progbar.update(self, current, values, finalize)
#     179 if finalize:
#     180     message += "\n"
# --> 182 io_utils.print_msg(message, line_break=False)
#     183 self._prev_total_width = total_width
#     184 message = ""
#
# File ~/anaconda3/envs/plard/lib/python3.10/site-packages/keras/src/utils/io_utils.py:99, in print_msg(message, line_break)
#      97     else:
#      98         sys.stdout.write(message)
# ---> 99     sys.stdout.flush()
#     100 else:
#     101     logging.info(message)
#
# File ~/anaconda3/envs/plard/lib/python3.10/site-packages/ipykernel/iostream.py:578, in OutStream.flush(self)
#     576     self.pub_thread.schedule(evt.set)
#     577     # and give a timeout to avoid
# --> 578     if not evt.wait(self.flush_timeout):
#     579         # write directly to __stderr__ instead of warning because
#     580         # if this is happening sys.stderr may be the problem.
#     581         print("IOStream.flush timed out", file=sys.__stderr__)
#     582 else:
#
# File ~/anaconda3/envs/plard/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/plard/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
#save model
autoencoder.save('0507test.keras')
